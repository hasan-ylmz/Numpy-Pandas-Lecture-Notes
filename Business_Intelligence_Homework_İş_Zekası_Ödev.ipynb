# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Automobile.csv")

# %%
df =pd.DataFrame(data)
print(df)
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
df.loc[1]
# Out:
# name            buick skylark 320
# mpg                          15.0
# cylinders                       8
# displacement                350.0
# horsepower                  165.0
# weight                       3693
# acceleration                 11.5
# model_year                     70
# origin                        usa
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# name            buick skylark 320
# mpg                          15.0
# cylinders                       8
# displacement                350.0
# horsepower                  165.0
# weight                       3693
# acceleration                 11.5
# model_year                     70
# origin                        usa
# Name: 1, dtype: object

# %%
df.iloc[:5]
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.loc[:4]
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.iloc[:1, :3]
# Out:
#                         name   mpg  cylinders
# 0  chevrolet chevelle malibu  18.0          8

# %%
df.loc[:0 , ["name","mpg","cylinders"]]
# Out:
#                         name   mpg  cylinders
# 0  chevrolet chevelle malibu  18.0          8

# %%
df.iloc[3:6, 2:4]
# Out:
#    cylinders  displacement
# 3          8         304.0
# 4          8         302.0
# 5          8         429.0

# %%
df.loc[3:5,["cylinders","displacement"]]
# Out:
#    cylinders  displacement
# 3          8         304.0
# 4          8         302.0
# 5          8         429.0

# %%
df.loc[::-1 , ::-1]
# Out:
#      origin  model_year  acceleration  weight  horsepower  displacement  \
# 397     usa          82          19.4    2720        82.0         119.0
# 396     usa          82          18.6    2625        79.0         120.0
# 395     usa          82          11.6    2295        84.0         135.0
# 394  europe          82          24.6    2130        52.0          97.0
# 393     usa          82          15.6    2790        86.0         140.0
# ..      ...         ...           ...     ...         ...           ...
# 4       usa          70          10.5    3449       140.0         302.0
# 3       usa          70          12.0    3433       150.0         304.0
# 2       usa          70          11.0    3436       150.0         318.0
# 1       usa          70          11.5    3693       165.0         350.0
# 0       usa          70          12.0    3504       130.0         307.0
#
#      cylinders   mpg                       name
# 397          4  31.0                 chevy s-10
# ...

# %%
df.iloc[::-1, ::-1]
# Out:
#      origin  model_year  acceleration  weight  horsepower  displacement  \
# 397     usa          82          19.4    2720        82.0         119.0
# 396     usa          82          18.6    2625        79.0         120.0
# 395     usa          82          11.6    2295        84.0         135.0
# 394  europe          82          24.6    2130        52.0          97.0
# 393     usa          82          15.6    2790        86.0         140.0
# ..      ...         ...           ...     ...         ...           ...
# 4       usa          70          10.5    3449       140.0         302.0
# 3       usa          70          12.0    3433       150.0         304.0
# 2       usa          70          11.0    3436       150.0         318.0
# 1       usa          70          11.5    3693       165.0         350.0
# 0       usa          70          12.0    3504       130.0         307.0
#
#      cylinders   mpg                       name
# 397          4  31.0                 chevy s-10
# ...
