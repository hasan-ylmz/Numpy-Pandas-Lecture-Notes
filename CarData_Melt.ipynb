# %%
import pandas as pd

# %%
data = pd.read_csv("/content/cardata.csv")
data.head()
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
melted_df2 = df.melt()
melted_df2
# Out:
#       variable    value
# 0     Car_Name     ritz
# 1     Car_Name      sx4
# 2     Car_Name     ciaz
# 3     Car_Name  wagon r
# 4     Car_Name    swift
# ...        ...      ...
# 2704     Owner        0
# 2705     Owner        0
# 2706     Owner        0
# 2707     Owner        0
# 2708     Owner        0
#
# [2709 rows x 2 columns]

# %%
melted_df = pd.melt(df, id_vars=['Car_Name'], value_vars=['Fuel_Type'], var_name='Feature', value_name='Value')
melted_df
# Out:
#     Car_Name    Feature   Value
# 0       ritz  Fuel_Type  Petrol
# 1        sx4  Fuel_Type  Diesel
# 2       ciaz  Fuel_Type  Petrol
# 3    wagon r  Fuel_Type  Petrol
# 4      swift  Fuel_Type  Diesel
# ..       ...        ...     ...
# 296     city  Fuel_Type  Diesel
# 297     brio  Fuel_Type  Petrol
# 298     city  Fuel_Type  Petrol
# 299     city  Fuel_Type  Diesel
# 300     brio  Fuel_Type  Petrol
#
# [301 rows x 3 columns]
